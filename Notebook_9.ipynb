# %% [markdown]
# # Notebook 9
# # Sunint Bindra

# %%
import numpy as np
# Importing standard Qiskit libraries
from qiskit import QuantumCircuit, execute, transpile, Aer, IBMQ
from qiskit.tools.jupyter import *
from qiskit.visualization import *
from ibm_quantum_widgets import *

# Loading your IBM Quantum account(s)
provider = IBMQ.load_account()
print('Libraries imported successfully!')
# Out:
# Libraries imported successfully!

# %%
# Quantum circuit with 2 qubits and 2 classical bits. 
# Adding an H gate to qubit 0, and an X gate to qubit 1
qc = QuantumCircuit(2,2)
qc.h(0)
qc.x(1)
qc.draw()

# %%
# Adding measurements to the circuit 
qc.measure([0,1],[0,1])
qc.draw()

# %%
# Simulating circuit using the QASM simulator and plotting histogram 
backend = Aer.get_backend('qasm_simulator') 
job = execute(qc,backend, shots = 1024) 
result = job.result()

counts = result.get_counts()
plot_histogram(counts)

# %%
# Quantum circuit with 2 qubits and 2 classical bits 
# Adding an H gate to qubit 0 and an CX gate with qubit 0 as control and qubit 1 as target 
qc = QuantumCircuit(2,2)
qc.h(0)
qc.cx(0,1)
qc.measure([0,1],[0,1]) # Adding measurements to circuit 
qc.draw()

# %%
# Simulating circuit using the QASM simulator and plotting histogram 
backend = Aer.get_backend('qasm_simulator') 
job = execute(qc,backend, shots = 1024) 
result = job.result()

counts = result.get_counts()
plot_histogram(counts)

# %%
# Block 6: Finding least busy quantum computer
from qiskit.providers.ibmq import least_busy
backend = least_busy(provider.backends(filters=lambda x: x.configuration().n_qubits >= 2 and 
                                        not x.configuration().simulator and x.status().operational==True))
print(backend)
# Out:
# ibmq_manila

# %%
# Block 7: Running  circuit using least busy QC and plotting histogram
job = execute(qc,backend, shots = 1024) 
result = job.result()

counts = result.get_counts()
plot_histogram(counts)

# %%
# Quantum circuit with 3 qubits and 3 classical bits
qc = QuantumCircuit(3,3)
qc.h(0) # Adding an H gate to qubit 0 
qc.cx(0,1 ) # Adding a CX gate with qubit 0 as control and 1 as target 
qc.cx(1,2) # Adding another CX with qubit 1 as control and 2 as target
qc.measure([0,1,2],[0,1,2]) # Adding measurements to all 3 qubits and draw the circuit
qc.draw()

# %%
# Simulating circuit using QASM simulator and plotting histogram
backend = Aer.get_backend('qasm_simulator') 
job = execute(qc,backend, shots = 1024) 

counts = result.get_counts()
plot_histogram(counts)
